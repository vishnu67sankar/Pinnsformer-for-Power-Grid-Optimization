# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
tl_lr1e_3 = [6841.5254, 1418.9711, 885.0148, 697.5260, 583.196, 454.0759,  342.6226, 311.0449, 262.3765, 239.6482]
tl_lr1e_4 = [5696.5376, 1146.2493, 808.2555, 643.3077, 537.6411, 461.5560, 404.9737, 363.6426, 334.0615, 306.5583]
tl_lr1e_5 = [39443.1914, 6131.8467, 4507.4727, 3672.1985, 3123.8215, 2747.2964, 2410.6465, 2132.6584, 1897.6481, 1698.0983]

# %%
epochs = np.arange(1, 11)

plt.figure(figsize=(8,6))
plt.plot(epochs, tl_lr1e_3, marker='o', label='lr=1e-3')
plt.plot(epochs, tl_lr1e_4, marker='s', label='lr=1e-4')
plt.plot(epochs, tl_lr1e_5, marker='^', label='lr=1e-5')

plt.xlabel('Epoch')
plt.ylabel('Total Error')
plt.title('Learning Rate')
plt.legend()
plt.grid(True)
# plt.tight_layout()

# %%
clip_grad = [306, 167, 114, 90, 73, 62, 53, 49, 46, 43, 40.5, 37.8]
clip_nograd = [212, 127, 101, 85, 69, 60, 48, 45, 46, 45, 43, 48]

epochs = np.arange(2, len(clip_grad)+2)*10

plt.figure(figsize=(8,6))
plt.plot(epochs, clip_grad, marker='o', label='With Clipping')
plt.plot(epochs, clip_nograd, marker='s', label='No Clipping')

plt.xlabel('Epoch')
plt.ylabel('Total Error')
plt.legend()
plt.grid(True)

# %%
p3_error_clip = [0.4762, 0.4067, 0.3885, 0.3683, 0.3891, 0.4256, 0.4587, 0.4899, 0.5012, 0.6512, 0.7591, 0.8100]
p3_error_noclip = [0.4762, 0.4067, 0.3885, 0.3683, 0.3423, 0.3019, 0.2681, 0.2390, 0.2017, 0.1765, 0.1281, 0.0711]


epochs = np.arange(2, len(clip_grad)+2)*10

plt.figure(figsize=(8,6))
plt.plot(epochs, p3_error_noclip, marker='o', label='With Clipping')
plt.plot(epochs, p3_error_clip, marker='s', label='No Clipping')

plt.xlabel('Epoch')
plt.ylabel('P3')
plt.legend()
plt.grid(True)

# %%
adamw = [1111.8115, 777.4368, 618.7722, 518.5036, 445.7996, 391.4268, 350.6111, 317.4099, 291.3751]
tl_lr1e_4 = [1146.2493, 808.2555, 643.3077, 537.6411, 461.5560, 404.9737, 363.6426, 334.0615, 306.5583]

epochs = np.arange(2, 11)

plt.figure(figsize=(8,6))
plt.plot(epochs, adamw, marker='o', label='AdamW')
plt.plot(epochs, tl_lr1e_4, marker='s', label='Adam')
# plt.plot(epochs, tl_lr1e_5, marker='^', label='lr=1e-5')

plt.xlabel('Epoch')
plt.ylabel('Total Error')
plt.title('Adam vs. AdamW')
plt.legend()
plt.grid(True)
# plt.tight_layout()

# %%
# tl_lr1e_4 = [1146.2493, 808.2555, 643.3077, 480.2467, 414.4391, 365.0849, 333.8753, 298.8226, 277.1991]

clip_grad = [1146.2493, 306, 167, 114, 90, 73, 62,]
tl_2heads = [1069.5554, 286, 157, 134, 110, 87, 77,]

# tl_2heads = [1069.5554, 739.0411, 578.7160, 500.6411, 461.5560, 404.9737, 363.6426, 334.0615, 306.5583]

epochs = [2, 10, 20, 30, 40, 50, 60]

# plt.figure(figsize=(8,6))
plt.plot(epochs, tl_2heads, marker='o', label='2 Layers')
plt.plot(epochs, clip_grad, marker='s', label='4 Layers')
# plt.plot(epochs, tl_lr1e_5, marker='^', label='lr=1e-5')

plt.xlabel('Epoch')
plt.ylabel('Total Error')
plt.title('Effec of Number of Layers')
plt.legend()
plt.grid(True)
# plt.tight_layout()
